# %% [markdown]
# # Introduction to Pandas
#
# ![alt text](http://i1.wp.com/blog.adeel.io/wp-content/uploads/2016/11/pandas1.png?zoom=1.25&fit=818%2C163)
#
# Pandas is an open-source, BSD-licensed Python library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language. You can think of pandas as an extremely powerful version of Excel, with a lot more features.
#
# ## **About iPython Notebooks**
#
# iPython Notebooks are interactive coding environments embedded in a webpage. You will be using iPython notebooks in this class. You only need to write code between the ### START CODE HERE ### and ### END CODE HERE ### comments. After writing your code, you can run the cell by either pressing "SHIFT"+"ENTER" or by clicking on "Run Cell" (denoted by a play symbol) in the left bar of the cell.
#
# **In this notebook you will learn -**
#
# * Series
# * DataFrames
# * Missing Data
# * GroupBy
# * Merging, Joining and Concatenating
# * Operations
# * Data Input and Output
#
# ## Importing Pandas
# To import Pandas simply write the following:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index.

# %%
from numpy.random import randn
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame.

# %%
df['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
# Pass a list of column names
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
# SQL Syntax (NOT RECOMMENDED!)
df.W
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %% [markdown]
# DataFrame Columns are just Series.

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %% [markdown]
# ** Removing Columns:**

# %% [markdown]
# **Note:** axis = 0 for selecting rows and axis = 1 for selecting columns.

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# Not inplace unless specified!
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# Can also drop rows this way:

# %%
df.drop('E',axis=0)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %% [markdown]
# ** Selecting Rows:**

# %%
df.loc['A']
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %% [markdown]
# Or select based off of index instead of label

# %%
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
df.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# **Exercise 2.1:**
#
# Create a new row **XZ** by adding the **X** and **Z** columns in the given dataframe **df**.

# %%
### START CODE HERE ### 
import pandas as pd
import numpy as np
from numpy.random import randn

np.random.seed(101)

df = pd.DataFrame(randn(5,4),index='A B C D E '.split(),columns='W X Y Z'.split())

df['XZ'] = df['X'] + df['Z']

df['XZ']
### END CODE HERE ###
# Out:
# A    1.131958
# B    0.286647
# C    0.151122
# D    0.196184
# E    2.662266
# Name: XZ, dtype: float64

# %% [markdown]
# **Expected Output:**
#
# XZ
#
# 1.131958
#
# 0.286647
#
# 0.151122
#
# 0.196184
#
# 2.662266

# %% [markdown]
# **Exercise 2.2:**
#
# Delete the newly created column **XZ** and the rows **D** and **E**(don't inplace).

# %%
### START CODE HERE ### 
import pandas as pd
import numpy as np
from numpy.random import randn

np.random.seed(101)

df = pd.DataFrame(randn(5,4),index='A B C D E '.split(),columns='W X Y Z'.split())


df['new'] = df['W'] + df['Y']
df['XZ'] = df['X'] + df['Z']


df.drop('D',axis=0,inplace=True)
df.drop('E',axis=0,inplace=True)
#df.drop('XZ,axis=1')
df
### END CODE HERE ###
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
df
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %%
df>0
# Out:
#        W      X      Y      Z    new    XZ
# A   True   True   True   True   True  True
# B   True  False  False   True  False  True
# C  False   True   True  False  False  True

# %% [markdown]
# Here you can see that it gives boolean values instead of the actual numbers. So we need to pass the argument in the form of a list.

# %%
df[df>0]
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118       NaN       NaN  0.605965       NaN  0.286647
# C       NaN  0.740122  0.528813       NaN       NaN  0.151122

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647

# %%
df[df['W']>0]['Y']
# Out:
# A    0.907969
# B   -0.848077
# Name: Y, dtype: float64

# %%
df[df['W']>0][['Y','X']]
# Out:
#           Y         X
# A  0.907969  0.628133
# B -0.848077 -0.319318

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
df[(df['W']>0) & (df['Y'] > 1)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z, new, XZ]
# Index: []

# %% [markdown]
# **Exercise 2.3:**
#
# Show the dataframe **df** with the negative values of **X** and positive values of **W**.

# %%
### START CODE HERE ### 
df[(df['W']>0) & (df['X'] < 1)]
### END CODE HERE ###
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
df
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %%
# Reset to default 0,1...n index
df.reset_index()
# Out:
#   index         W         X         Y         Z       new        XZ
# 0     A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# 1     B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# 2     C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %%
df
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %%
df
# Out:
#           W         X         Y         Z       new        XZ
# A  2.706850  0.628133  0.907969  0.503826  3.614819  1.131958
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959  0.286647
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355  0.151122

# %% [markdown]
# ## Multi-Index and Index Hierarchy
#
# Let us go over how to work with Multi-Index, first we'll create a quick example of what a Multi-Indexed DataFrame would look like:

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# G2 1  0.166905  0.184502
#    2  0.807706  0.072960
#    3  0.638787  0.329646

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.302665  1.693723
# 2 -1.706086 -1.159119
# 3 -0.134841  0.390528

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    0.302665  1.693723
#       2   -1.706086 -1.159119
#       3   -0.134841  0.390528
# G2    1    0.166905  0.184502
#       2    0.807706  0.072960
#       3    0.638787  0.329646

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.302665  1.693723
# 2   -1.706086 -1.159119
# 3   -0.134841  0.390528

# %%
df.xs(['G1',1])
# Out:
# A    0.302665
# B    1.693723
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1     0.302665  1.693723
# G2     0.166905  0.184502

# %% [markdown]
# # Great Job!
